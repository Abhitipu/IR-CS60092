# %%
import pickle
import numpy as np
import pandas as pd
from collections import Counter
# import ipdb
np.seterr(divide='ignore', invalid='ignore')


def compute_tf_idf(word_list, op_type, V, N, idf):
  """
  Applies the term freq operation on the word list

  Args:
      word_list (token_id, freq): 
      op_type (str): "lan"
      V (int): size of the vocab
      N (int): total no of docs
  Returns:
      final_vector : the vector representing the term
  """
  print("computing tf id")
  
  op_type = op_type.lower()
  final_vector = np.zeros(V)
  idf_vector = np.zeros(V)
  
  # First operation
  if op_type[0] not in "lan":
    return Exception("Invalid operation")
  
  else:
    for idx, freq in word_list:
      final_vector[idx] = freq
          
    if op_type[0] == "l":
      final_vector = np.log(1 + final_vector)
      
    elif op_type[0] == "a":
      final_vector = 0.5 + 0.5 * final_vector / np.max(final_vector)

  # Second operation
  if op_type[1] not in "ntp":
    return Exception("Invalid operation")
  
  else:
    # final_vector = final_vector + 1e-20
    ipdb.set_trace()
    for idx, freq in word_list:
      idf_vector[idx] = idf[idx]

    if op_type[1] == "t":
      idf_vector = np.log(N / idf_vector )
      
    elif op_type[1] == "p":
      idf_vector = np.log(N / idf_vector - 1)

  final_vector = final_vector * idf_vector
  
  # Third operation
  if op_type[2] not in "cn":
    return Exception("Invalid operation")
  
  return final_vector / np.linalg.norm(final_vector) if op_type[2] == "c" else final_vector


def transpose_inv_idx(inv_idx):
  """
  Takes a transpose of the inverted index

  Args:
      inv_idx (dict): token to (doc_id, freq) mapping

  Returns:
      new_idx(dict): doc_id to (token, freq) mapping
      mapping(dict): token to token_id mapping
      idf(dict): token to idf mapping
  """
  
  idf = dict()
  N = len(inv_idx.keys())
  new_idx = dict()
  mapper = dict()
  
  for idx, key in enumerate(sorted(inv_idx.keys())):
      mapper[key] = idx
      idf[key] = np.log(N / len(inv_idx[key]))
      for cord_id, freq in inv_idx[key]:
        if cord_id not in new_idx:
          new_idx[cord_id] = []
        new_idx[cord_id].append((idx, freq))
  
  return new_idx, mapper, idf


def get_query_postings(queries, mapper):
  """
  Get a map from query ids to tokens

  Args:
      queries (DataFrame): The queries dataframe
      mapper (dict): token to token_id mapping

  Returns:
      
      query_vector: The mapping from query_id to tokens
  """
  
  query_vector = dict()

  for idx, query in zip(queries["topic-id"], queries["query"]):
    words = query.split()
    query_vector[idx] = []
    tokens = []

    for word in words:
      if word in mapper:
        tokens.append(mapper[word]) 
            
    query_vector[idx] = list(Counter(tokens).items())
  
  return query_vector


def get_ranks(new_idx, query_vector, V, method, output_file, idf):
  """Returns a dict containing the query id vs the docs

  Args:
      new_idx (dict): doc_id to (token, freq) mapping
      query_vector (dict): query_id to tokens mapping
      V (int): vocab size
  """
  
  doc_method, query_method = method.split('.')
  
  with open(output_file, "w") as f:
    for query_id, query_token_list in query_vector.items():
      scores = []
      f.write(str(query_id) + ",")
      query_vector = compute_tf_idf(query_token_list, query_method, V, len(new_idx.keys()), idf)
      
      for doc_id, doc_token_list in new_idx.items():
        doc_vector = compute_tf_idf(doc_token_list, doc_method, V, len(new_idx.keys()), idf)
        scores.append((doc_id, np.dot(query_vector, doc_vector)))
        
      scores.sort(key=lambda x: x[1], reverse=True) 
      scores = scores[:50]
      for score in scores:
        f.write(str(score[0]) + ",")
      f.write("\n")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15748\3944363885.py in <module>
#       3 import pandas as pd
#       4 from collections import Counter
# ----> 5 import ipdb
#       6 np.seterr(divide='ignore', invalid='ignore')
#       7
#
# ModuleNotFoundError: No module named 'ipdb'

# %%
inv_idx_file = "model_queries_10.bin"
query_file = "./Data/queries_10.txt"
configs = {
"lnc.ltc": "Assignment2_10_ranked_list_A.csv",
"lnc.lpc": "Assignment2_10_ranked_list_B.csv",
"anc.apc": "Assignment2_10_ranked_list_C.csv"
}

# Load old inverted index
with open(inv_idx_file, 'rb') as f:
    inv_idx = pickle.load(f)

# Transpose inverted index for optimizing space
new_idx, mapper, idf = transpose_inv_idx(inv_idx)  

# Get queries to tokens mapping 
queries = pd.read_csv(query_file)
query_vector = get_query_postings(queries, mapper)

# Get the ranks and save for different configs
for config, output_file in configs.items():
    get_ranks(new_idx, query_vector, len(mapper), config, output_file, idf)
# Out:
# computing tf id
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15748\439349145.py in <module>
#      20 # Get the ranks and save for different configs
#      21 for config, output_file in configs.items():
# ---> 22     get_ranks(new_idx, query_vector, len(mapper), config, output_file, idf)
#
# ~\AppData\Local\Temp\ipykernel_15748\3880756842.py in get_ranks(new_idx, query_vector, V, method, output_file, idf)
#     137       scores = []
#     138       f.write(str(query_id) + ",")
# --> 139       query_vector = compute_tf_idf(query_token_list, query_method, V, len(new_idx.keys()), idf)
#     140
#     141       for doc_id, doc_token_list in new_idx.items():
#
# ~\AppData\Local\Temp\ipykernel_15748\3880756842.py in compute_tf_idf(word_list, op_type, V, N, idf)
#      45   else:
#      46     # final_vector = final_vector + 1e-20
# ---> 47     ipdb.set_trace()
#      48     for idx, freq in word_list:
#      49       idf_vector[idx] = idf[idx]
#
# NameError: name 'ipdb' is not defined

# %%
a = 1

# %%
import ipdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15748\2241182999.py in <module>
# ----> 1 import ipdb
#
# ModuleNotFoundError: No module named 'ipdb'

# %%
# !pip list
# Out:
# Package            Version
# ------------------ ---------
# backcall           0.2.0
# click              8.1.3
# colorama           0.4.5
# decorator          5.1.1
# importlib-metadata 4.12.0
# ipdb               0.13.9
# ipython            7.34.0
# jedi               0.18.1
# joblib             1.1.0
# matplotlib-inline  0.1.6
# nltk               3.7
# numpy              1.21.6
# pandas             1.3.5
# parso              0.8.3
# pickleshare        0.7.5
# pip                22.2.2
# prompt-toolkit     3.0.32
# Pygments           2.13.0
# python-dateutil    2.8.2
# pytz               2022.2.1
# regex              2022.8.17
# setuptools         63.4.3
# six                1.16.0
# toml               0.10.2
# tqdm               4.64.1
# traitlets          5.5.0
# typing_extensions  4.3.0
# wcwidth            0.2.5
# wheel              0.37.1
# zipp               3.8.1
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: E:\Books\IR\project\IR-project\Assn1\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
# !pip install ipdb
# Out:
# Requirement already satisfied: ipdb in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (0.13.9)
# Requirement already satisfied: decorator in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipdb) (5.1.1)
# Requirement already satisfied: toml>=0.10.2 in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipdb) (0.10.2)
# Requirement already satisfied: setuptools in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipdb) (63.4.3)
# Requirement already satisfied: ipython>=7.17.0 in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipdb) (7.34.0)
# Requirement already satisfied: traitlets>=4.2 in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipython>=7.17.0->ipdb) (5.5.0)
# Requirement already satisfied: jedi>=0.16 in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipython>=7.17.0->ipdb) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipython>=7.17.0->ipdb) (3.0.32)
# Requirement already satisfied: colorama in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipython>=7.17.0->ipdb) (0.4.5)
# Requirement already satisfied: pygments in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipython>=7.17.0->ipdb) (2.13.0)
# Requirement already satisfied: pickleshare in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipython>=7.17.0->ipdb) (0.7.5)
# Requirement already satisfied: matplotlib-inline in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipython>=7.17.0->ipdb) (0.1.6)
# Requirement already satisfied: backcall in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from ipython>=7.17.0->ipdb) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from jedi>=0.16->ipython>=7.17.0->ipdb) (0.8.3)
# Requirement already satisfied: wcwidth in e:\books\ir\project\ir-project\assn1\venv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.17.0->ipdb) (0.2.5)
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: E:\Books\IR\project\IR-project\Assn1\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
import pickle
import glob
import json

# %%
inv_idx_file = "model_queries_10.bin"
# Load old inverted index
with open(inv_idx_file, 'rb') as f:
    inv_idx = pickle.load(f)

# %%
len(inv_idx.keys())
# Out:
# 146080

# %%
docs = set()
for k in inv_idx.keys():
    for d in inv_idx[k]:
        docs.add(d[0])

# %%
len(docs)
# Out:
# 37330

# %%
import pandas as pd

# %%
df = pd.read_csv('Data/id_mapping.csv')

# %%
df.describe()
# Out:
#          cord_id                                  paper_id
# count      52471                                     52471
# unique     52442                                     52471
# top     hmqx925r  0001418189999fea7f7cbe3e82703d71c85a6fe5
# freq           2                                         1

# %%
def build_raw_doc(data_dir, coord_file):
  """
    Returns a dictionary of raw documents 
    indexed by the cord id
  """
  # Get the cord ids
  id_maps = pd.read_csv(coord_file, index_col='paper_id')

  my_raw_documents = dict()
  counter = 0
  for filename in glob.iglob(f"{data_dir}*.json", recursive = True):
    if(counter%1000 == 0):
      print(f"Iteration {counter} started")
    counter += 1
    with open(filename, 'r') as f:
        data = json.load(f)
      
    # Get the paper id
    paper_id = data['paper_id']
    # Get the associated cord id
    cord_id = id_maps.loc[paper_id].cord_id
    # Create if doesnt exist
    if cord_id not in my_raw_documents:
      my_raw_documents[cord_id] = ""
      
    # Get all the text from the files
    # for line in data['abstract']:
    #   my_raw_documents[cord_id]+=(" "+line['text'])
      
  return my_raw_documents

# %%
data_dir = 'Data/_CORD-19/'
coord_file = 'Data/id_mapping.csv'

# %%
my_raw_documents = build_raw_doc(data_dir, coord_file)
# Out:
# Iteration 0 started
# Iteration 1000 started
# Iteration 2000 started
# Iteration 3000 started
# Iteration 4000 started
# Iteration 5000 started
# Iteration 6000 started
# Iteration 7000 started
# Iteration 8000 started
# Iteration 9000 started
# Iteration 10000 started
# Iteration 11000 started
# Iteration 12000 started
# Iteration 13000 started
# Iteration 14000 started
# Iteration 15000 started
# Iteration 16000 started
# Iteration 17000 started
# Iteration 18000 started
# Iteration 19000 started
# Iteration 20000 started
# Iteration 21000 started
# Iteration 22000 started
# Iteration 23000 started
# Iteration 24000 started
# Iteration 25000 started
# Iteration 26000 started
# Iteration 27000 started
# Iteration 28000 started
# Iteration 29000 started
# Iteration 30000 started
# Iteration 31000 started
# Iteration 32000 started
# Iteration 33000 started
# Iteration 34000 started
# Iteration 35000 started
# Iteration 36000 started
# Iteration 37000 started
# Iteration 38000 started
# Iteration 39000 started
# Iteration 40000 started
# Iteration 41000 started
# Iteration 42000 started
# Iteration 43000 started
# Iteration 44000 started
# Iteration 45000 started
# Iteration 46000 started
# Iteration 47000 started
# Iteration 48000 started
# Iteration 49000 started
# Iteration 50000 started
# Iteration 51000 started
# Iteration 52000 started

# %%
my_raw_documents
# Out:
# {'k2uydo6j': '',
#  'o81b9htu': '',
#  's31mbs7a': '',
#  '0tqwjdhd': '',
#  '9k0bsktb': '',
#  '5k0ktboh': '',
#  'zugd4rji': '',
#  'g24zbcd5': '',
#  'h7iykrrl': '',
#  'vxpyony9': '',
#  '5f25yqzf': '',
#  'uijwq8gx': '',
#  'oveybgbc': '',
#  'q356npb7': '',
#  '0dxl6t4p': '',
#  'xcii4zlt': '',
#  'podcwiyt': '',
#  'o684am08': '',
#  'ay4wxf88': '',
#  'barmkkwx': '',
#  'hj77rg85': '',
#  '8cwwx7v3': '',
#  'y0c39p7a': '',
#  'rjh1ahi6': '',
#  'gdveadvv': '',
#  'dgjypnga': '',
#  'bnnw8cpn': '',
#  '8sgbf22u': '',
#  'tldg8c94': '',
#  '3mqs7mj1': '',
#  'm5ho8jqp': '',
#  '21e00h2d': '',
#  'aq94ybqi': '',
#  'p5orjg14': '',
#  'ya81rc2n': '',
#  '1bqpc3x3': '',
#  'ky3icm1m': '',
#  'mrsmwxvo': '',
#  'i8ywbu6u': '',
#  'zxln007a': '',
#  'lndtq585': '',
#  'm2xtdi6u': '',
#  'd938zs2e': '',
#  '38tajokl': '',
#  'rac71o9c': '',
#  '3877dfj9': '',
#  '05q8aki0': '',
#  'vgw8uz83': '',
#  '54hh0ppq': '',
#  'zu9a0tfq': '',
#  'gblx3u2k': '',
#  'r0ej6jep': '',
#  'ija2pb97': '',
#  'oqte7dx2': '',
#  'ouafdyyc': '',
#  'uhv28ji7': '',
#  'fgjpuzm6': '',
#  'q14gfwnt': '',
#  '8bzu3jiu': '',
#  '60qw00zc': '',
#  'fitte5bf': '',
#  'zi9u0nks': '',
#  'hm8d42fq': '',
#  'bmc8w3cn': '',
#  '4svsmhob': '',
#  'nh2rr0n9': '',
#  'okdilram': '',
#  'ngo0fyew': '',
#  'tzq389yi': '',
#  'k2vbgqk7': '',
#  'qbemfymp': '',
#  'o1xic89x': '',
#  'da36693q': '',
#  'tx2vqr64': '',
#  'vxze3to7': '',
#  'o49ah12j': '',
#  'v48c2798': '',
#  'zz7i6bsa': '',
#  'rtzeip5s': '',
#  'ekal5251': '',
#  'lyuy6pot': '',
#  '09tkcvtc': '',
#  '8n500evn': '',
#  '11esz6lk': '',
#  'nkw4wqyb': '',
#  'mugsglc0': '',
#  '4jg4t8po': '',
#  'ja7zw7bf': '',
#  'e99fw336': '',
#  'agtcfov1': '',
#  'kgje01qy': '',
#  'zvrfqkol': '',
#  '0zohar80': '',
#  'vw6kpuz4': '',
#  '05emvz2v': '',
#  'l5kocy4f': '',
#  'qqijjcjd': '',
#  '8phdtv7h': '',
#  'st1djxx6': '',
#  'a7yovhvk': '',
#  'nmrh4ncw': '',
#  '2vdyeeb6': '',
#  '7sno0pih': '',
#  '9p82ryd4': '',
#  '7jjmp51n': '',
#  'rgmurgbf': '',
#  '2841vq8w': '',
#  '66qoykl1': '',
#  '6do0r4en': '',
#  'ytxrrslz': '',
#  'q58ffgsk': '',
#  '34v1rny8': '',
#  'mpdizhjw': '',
#  'klliuizs': '',
#  'rvj1ssfp': '',
#  'forh7lw4': '',
#  '7hyr8x0l': '',
#  'egby8kv5': '',
#  'f7vhyau9': '',
#  'kuuyvf90': '',
#  'btdbv2tk': '',
#  'qx99ytpv': '',
#  'uieedtv2': '',
#  'jjsfxm49': '',
#  '5055n556': '',
#  'r6b34tjm': '',
#  'ifo4p7yk': '',
#  '4a4n3473': '',
#  'gmznmdgh': '',
#  'gg4qi4tj': '',
#  'h8t8u4w3': '',
#  '8it1zdvq': '',
#  'kt6gllms': '',
#  'npu2y39j': '',
#  'hmm4qh1a': '',
#  '0v5wo0ty': '',
#  '0wqbr9a2': '',
#  'rv2m3u13': '',
#  'aem15g84': '',
#  'hphn7cs6': '',
#  'wp1hd5w9': '',
#  'l7ymcyw7': '',
#  '6xyipioz': '',
#  '6pxwamrf': '',
#  'w1e60xds': '',
#  'ib8vcsd0': '',
#  'rc00z760': '',
#  'fae3sczm': '',
#  'rxtptyaj': '',
#  '7jn2snih': '',
#  'ycywtpzj': '',
#  'qeq33nns': '',
#  'led2huz4': '',
#  'wzj2glte': '',
#  '2behvv3b': '',
#  '18ohr5we': '',
#  'jfu3jlt7': '',
#  'akr0shvb': '',
#  'g6ord9pd': '',
#  'e1hl1nvz': '',
#  '4h83ny0c': '',
#  '80ev0j5a': '',
#  'xkenld6e': '',
#  'qi9ex3l5': '',
#  'vsinwqnr': '',
#  'hcoonxax': '',
#  'wqw6i8ly': '',
#  'pdjxet20': '',
#  'r5zydz79': '',
#  'xoeugrzn': '',
#  '2fhiz3an': '',
#  'th4srh88': '',
#  '3w6hivv8': '',
#  'eob22inx': '',
#  '81csdj78': '',
#  'qjviy4p6': '',
#  'ga9apqo1': '',
#  'ihhu7nef': '',
#  'huo2czjf': '',
#  'hc7wej3i': '',
#  'q8e08pq0': '',
#  '6zk2g3o1': '',
#  'gzrtheuc': '',
#  '91jofoan': '',
#  'pir3xmbw': '',
#  'izjcyd4d': '',
#  '0xg94v1e': '',
#  'hofbtjr5': '',
#  'fn0l26i0': '',
#  '8xlcm3t2': '',
#  'y5kptngx': '',
#  'rs0unxoq': '',
#  'dzn0y9nc': '',
#  '0lz716kk': '',
#  'ewe4k0m9': '',
#  'oa24b5to': '',
#  'zpc9r4cl': '',
#  'pzmnrtod': '',
#  'yygb25wm': '',
#  'xma1v90f': '',
#  'cuq1tqgm': '',
#  '3f1weh96': '',
#  'vuvtt13q': '',
#  'wyhnquw6': '',
#  '8rf0xigw': '',
#  '8v25etag': '',
#  '80e5xkht': '',
#  'dnxdamsu': '',
#  'lc6t9x1x': '',
#  '0jojon1s': '',
#  'fy4w7xz8': '',
#  'idd8uq9h': '',
#  '6t8wadi5': '',
#  'x5btuxrq': '',
#  'm5mjvtca': '',
#  'zt6i3o86': '',
#  'cghi9mzt': '',
#  'j36vajdi': '',
#  'd950qa2w': '',
#  'x2ky94b0': '',
#  'tcy7jrth': '',
#  'p9si8rhc': '',
#  'qoynj85f': '',
#  'ltp17r6v': '',
#  'eyobjalw': '',
#  'dn0n1exf': '',
#  '0cyi5262': '',
#  'ek8w6vzw': '',
#  'wxst10hm': '',
#  '6jittbis': '',
#  'vpw4ghfw': '',
#  'tgj647hh': '',
#  'zak8iivx': '',
#  'jubwcobb': '',
#  'ggdd5rrb': '',
#  'k3zxudok': '',
#  'birkvwgk': '',
#  'lreguu45': '',
#  'jgssstn3': '',
#  'j7swau26': '',
#  'kxivgxbg': '',
#  '5wztvpul': '',
#  '4bcwrne8': '',
#  'o5545c1x': '',
#  'vl7yqnlg': '',
#  'cm1bq9zq': '',
#  'yhh3ydok': '',
#  '1gf8n3lf': '',
#  '6lnxb0px': '',
#  '569a86u3': '',
#  'iuu8vmwy': '',
#  'lng7g1fu': '',
#  '0idn1esa': '',
#  'aoa92919': '',
#  'shi77p40': '',
#  's7k8ldrj': '',
#  'p5uihiwt': '',
#  'vgw65iw9': '',
#  '1jon8hu5': '',
#  '96migwaq': '',
#  'ezas9ird': '',
#  'iat80b4l': '',
#  '29m062q4': '',
#  'siagb7x1': '',
#  'tq9kjozt': '',
#  'todneigr': '',
#  'k9gu6j2k': '',
#  '55yzkch7': '',
#  'xn0u0wj6': '',
#  'bep0xtxa': '',
#  '5zclxuf1': '',
#  'k2kmhfha': '',
#  '50pupre2': '',
#  '5xgurlue': '',
#  'q1uje0xq': '',
#  'unj4sj56': '',
#  'zh0zn5rx': '',
#  'vqrtwd5k': '',
#  '2kyfboly': '',
#  'is0lp6no': '',
#  '8giv33cp': '',
#  'f2vds1n7': '',
#  'ucxm2b2l': '',
#  'sn9s0v8q': '',
#  'h4d2f2sb': '',
#  '10bu7iwg': '',
#  '01tncjq0': '',
#  'dfg021y0': '',
#  'i55gwn3s': '',
#  'eebtibz3': '',
#  'iptisi1m': '',
#  'ip4bxki8': '',
#  'dma4d74d': '',
#  'e3l5xtc2': '',
#  '2bhzzc7t': '',
#  '6qcq92ot': '',
#  'dernekty': '',
#  '89t10psi': '',
#  '50r61l1x': '',
#  '5xr7qh5c': '',
#  'l5xcrql0': '',
#  'v4xd4k6x': '',
#  'wutnzzhg': '',
#  '6ci0e3kc': '',
#  'pqls3qtc': '',
#  'b4etsi5c': '',
#  '8oki8xr2': '',
#  '52zjm9jt': '',
#  'zdqiozxo': '',
#  'ndao9wcj': '',
#  'h6si6lwx': '',
#  'vbw2g4ry': '',
#  'kjqtvcfg': '',
#  'r4snyxr9': '',
#  '6xkfpnaa': '',
#  '276zwah5': '',
#  '66m6evcq': '',
#  'hqxiyxfj': '',
#  'ygg093ns': '',
#  'gvgwyzkt': '',
#  'wek9wp6u': '',
#  'mvr66roh': '',
#  '3iqwf7cw': '',
#  '44u8mcfo': '',
#  'v8ga78l4': '',
#  'ceyxgf83': '',
#  'b6zhp2ei': '',
#  'tzfbhd0v': '',
#  'plqel38y': '',
#  '8stgwlfp': '',
#  't7w407it': '',
#  'aoti88v7': '',
#  'y9bxc0x1': '',
#  'lrzhnyj5': '',
#  'gycxe3vs': '',
#  '5rz7gk3m': '',
#  '8je5q62j': '',
#  'dkn3z77f': '',
#  '5to8n2nm': '',
#  '34rz2hvl': '',
#  'dizrffw1': '',
#  'npc6dwk0': '',
#  'rqlnve7r': '',
#  '1ewhqpwb': '',
#  'i0txtkuz': '',
#  '8crvjzz4': '',
#  'cibkf9pz': '',
#  's9qvrkia': '',
#  'a7lf9bbg': '',
#  'c57impca': '',
#  's4pnq6j7': '',
#  'b0ajhnip': '',
#  'l4288mxw': '',
#  'tk3h4f92': '',
#  '99p5saho': '',
#  'di58oqe3': '',
#  '23b0nazy': '',
#  '0emio4rl': '',
#  'f2lkwfac': '',
#  'gdocdp1x': '',
#  'bqv0nbo7': '',
#  '2i45op25': '',
#  'x6m02voy': '',
#  '923cs2ll': '',
#  'x4ukvipc': '',
#  '5qri915n': '',
#  'eoo6y6hd': '',
#  'c8ksqtot': '',
#  'z103k5zn': '',
#  'hhge62sl': '',
#  'kggbh8c7': '',
#  'ptuqsq0q': '',
#  'ebe8qm1z': '',
#  'hb07pd98': '',
#  'mzv9jqxf': '',
#  '1m9b8tph': '',
#  'f21dknmb': '',
#  'kbdslkbr': '',
#  'i4q0ljb0': '',
#  'ckgmv7rt': '',
#  'ntqk4imv': '',
#  'wdgkm45r': '',
#  '81ykqsm0': '',
#  'qd44vv2h': '',
#  'r8m6cgv8': '',
#  'vi400eqv': '',
#  'br4fjveb': '',
#  'mpfmam46': '',
#  'yirs7kjg': '',
#  'ythjw9hj': '',
#  '0oqcx0az': '',
#  'czthv24p': '',
#  'ipyhofye': '',
#  'hm4l0oes': '',
#  'w5a05thf': '',
#  'zsy5gowg': '',
#  'b4krhwfj': '',
#  'a97um9x5': '',
#  'tktqlfgd': '',
#  '3g6uswt9': '',
#  'whj386wr': '',
#  '3aya6xil': '',
#  'ccp7ds1e': '',
#  '2rccocmg': '',
#  '7tzkttoz': '',
#  'w3rrl0sm': '',
#  'qublvlmo': '',
#  'u7egknq6': '',
#  'djuomhww': '',
#  'tu5lomzd': '',
#  '0cfafydb': '',
#  't51rmkwb': '',
#  'ym9j0ei0': '',
#  '2n4axtcn': '',
#  '9hv1tfzw': '',
#  'lrcxwtx7': '',
#  'svnqfi51': '',
#  'goy2gi94': '',
#  '9f1122qi': '',
#  'o0w8fj27': '',
#  'jn20f6xf': '',
#  'b4t3eadh': '',
#  'uxl8liil': '',
#  '2xlxjq0e': '',
#  'y8hazdrc': '',
#  '8a348729': '',
#  '75dqdnug': '',
#  'ismp2sf5': '',
#  'fmjo3gv2': '',
#  'mvdnqqb8': '',
#  '29qwlmeq': '',
#  'twmx5udk': '',
#  'gckqphhp': '',
#  'd9kkhzej': '',
#  '95zrth5d': '',
#  'tmeg7vou': '',
#  'vwfk96we': '',
#  'k56ccirb': '',
#  'cyxuz9qq': '',
#  'uzag8f3y': '',
#  'o6b6dcgd': '',
#  'tusqf260': '',
#  'odlq2kh8': '',
#  '5ca2e6wm': '',
#  'fqwjadan': '',
#  'c6hqrnj2': '',
#  'jz4zb8qp': '',
#  '47ovbto5': '',
#  'xge6mah1': '',
#  'c3d2rpzh': '',
#  'z54p3dk3': '',
#  '2740rfql': '',
#  'qd2xg5tz': '',
#  '4jpirkni': '',
#  'mscsw8z0': '',
#  '1ossrnum': '',
#  'xsg0j92t': '',
#  'p3vfo3ne': '',
#  'ojuq37ha': '',
#  'rfs7m6or': '',
#  '24q7p3m4': '',
#  '81lfh99h': '',
#  'b0fi9eky': '',
#  'xes47tlz': '',
#  '6sybvdjj': '',
#  'zd7smm8r': '',
#  'lcu1mgno': '',
#  '7vjdlt1v': '',
#  'ck8ilqo2': '',
#  'wnnsmx60': '',
#  'ps5bhbeb': '',
#  'r0r3ksw7': '',
#  '7v5xl1s3': '',
#  '0w04si16': '',
#  '4w0zezt4': '',
#  'ybr2ij5b': '',
#  'i6vuhaiv': '',
#  'mslm0auu': '',
#  'p1y6uuf1': '',
#  'i6tpz49j': '',
#  'zy2yc8gs': '',
#  'll4rxd9p': '',
#  'qgsi7x8a': '',
#  'kuqinczz': '',
#  'emi989ys': '',
#  'xy59hlr9': '',
#  '35rq2kio': '',
#  'fhwjk6xu': '',
#  '4t7fwnao': '',
#  'm2k8lf7v': '',
#  'iwd0l05p': '',
#  'oke8gfd9': '',
#  'll6lkhyd': '',
#  'zkdyyepy': '',
#  'd5s8f9zr': '',
#  'xhfnhmum': '',
#  '1br7nhzt': '',
#  'ka676pli': '',
#  'p1lpa4fu': '',
#  '0ewu7e1c': '',
#  '9x252vax': '',
#  '465ltmml': '',
#  'ovoli9dr': '',
#  'llnqzkqt': '',
#  'yebwy2nd': '',
#  'zgix8quw': '',
#  '5jugyncm': '',
#  'ita2okbx': '',
#  '5z3pbbfb': '',
#  't2jm1n77': '',
#  '2pwlwxue': '',
#  'u6v6bxwj': '',
#  'b0p1b4g8': '',
#  'vur1llau': '',
#  '5ymjmbz2': '',
#  'd13j2pt5': '',
#  '9uvr4592': '',
#  '6qz40fnv': '',
#  'a6h5u16x': '',
#  'd6dfvof7': '',
#  'enqf0gm4': '',
#  'u1e4e8d8': '',
#  'qzv030tr': '',
#  'v7xeubps': '',
#  'kxu6azsb': '',
#  'wsgb5s6z': '',
#  'h4tnz9x4': '',
#  'nls2zam3': '',
#  '66t5fjld': '',
#  'xepjrmnp': '',
#  '55ehw0j9': '',
#  'heogsh7i': '',
#  '15q6qr4z': '',
#  'xzidr8dv': '',
#  '6r43i2dv': '',
#  '41q1bm13': '',
#  'ogu3f3o5': '',
#  'jrwybas0': '',
#  'cl7evbr3': '',
#  '8gbk3mt9': '',
#  'j8ebp5dx': '',
#  '5uvmwj0i': '',
#  '5gkp9tlt': '',
#  'ycf9hgis': '',
#  '70hskj1o': '',
#  '30cx62vb': '',
#  'gm55tvcu': '',
#  'wyw5992m': '',
#  'lel5jqls': '',
#  'zdn2jtxk': '',
#  'f0x64uud': '',
#  'kweet9dh': '',
#  'as4qaan9': '',
#  'lqnjqpdj': '',
#  '3re38vir': '',
#  'tlj3wkqh': '',
#  '9v1ngo3r': '',
#  '2kfzor6d': '',
#  'qrebb2po': '',
#  'a097byk5': '',
#  '0njpw3zz': '',
#  'w3fcwcz3': '',
#  'syb1gpvd': '',
#  'bojfc3q0': '',
#  '0u6idk0m': '',
#  'fn9b7adi': '',
#  '9tgx0cjt': '',
#  'ou2cilvp': '',
#  'alxpzdkk': '',
#  'qhgvf35j': '',
#  '166su0tn': '',
#  'r8ghn9z0': '',
#  'oz2ztmzo': '',
#  'rhld75dy': '',
#  '65wokvyd': '',
#  '0dznbrs1': '',
#  'geq0uecd': '',
#  'h2g4d0uk': '',
#  'yvqk4woz': '',
#  '010vptx3': '',
#  '92bax8qs': '',
#  'keh7s758': '',
#  '0wc23ixy': '',
#  '9hknw4ws': '',
#  'tdjytql3': '',
#  '6szflw6v': '',
#  'ojfp7yey': '',
#  'n03zk9ni': '',
#  'z2rqz3jx': '',
#  'tsypurrr': '',
#  'hox1cqqc': '',
#  'qm9urt2w': '',
#  'i158kedv': '',
#  'xwwomnqu': '',
#  'c8yzoen7': '',
#  'p7t0ieif': '',
#  '2nddhxxo': '',
#  'z9ll837t': '',
#  '0dffcoi5': '',
#  'qq7rzmwj': '',
#  '19h2i631': '',
#  'wfkk7dsm': '',
#  '0b7aui02': '',
#  'd4j96em5': '',
#  'pfa3h2e8': '',
#  '9wugdrgi': '',
#  '81q44urp': '',
#  'yy9xp5ms': '',
#  'hn97yn3z': '',
#  'crnsk87x': '',
#  'sjmu0u3t': '',
#  'e7v4rfje': '',
#  'v5bb7mr1': '',
#  'jy8rhrd1': '',
#  'xad3k5aw': '',
#  'l6mwidbr': '',
#  '34ly9oiz': '',
#  'etckbqlp': '',
#  'xz15s6nj': '',
#  'u5ix7ytn': '',
#  'rraocx0f': '',
#  'ykx60xvf': '',
#  '9jd1bw1c': '',
#  '559mkh0z': '',
#  '9zf2h0xr': '',
#  '5a03euc0': '',
#  'wr73zrha': '',
#  'zowp10ts': '',
#  'bp8dqis1': '',
#  '6nh9lfkk': '',
#  '0m2ganys': '',
#  '0jp0z5kp': '',
#  'l297aj7w': '',
#  'zfheaem1': '',
#  '6wet13pv': '',
#  'zbz88pqx': '',
#  'qwgde9uu': '',
#  '9gp0qfn6': '',
#  'ujqtb0la': '',
#  'ui8apeiv': '',
#  'ax55awv1': '',
#  'bs4jczmw': '',
#  'cx3ex9ru': '',
#  'jyem5rvj': '',
#  'aesixn73': '',
#  'egkdfa0j': '',
#  'jjw560vw': '',
#  'i7munwu9': '',
#  'beoseizn': '',
#  'gjowq3ie': '',
#  'i7x50taa': '',
#  'rkf22met': '',
#  'hsy5plk2': '',
#  'e55vmgjr': '',
#  '7hv4w7ul': '',
#  'e5nxkvo7': '',
#  'cruvl0lr': '',
#  'buzd515o': '',
#  'sok56yga': '',
#  'vst2v5tw': '',
#  'j5kj65e4': '',
#  'ky1pxd7i': '',
#  'am4bgao8': '',
#  'j5rlgbl8': '',
#  '58txy376': '',
#  'c022ogee': '',
#  'otwwr83y': '',
#  '5ozdhuk0': '',
#  'btwrjr87': '',
#  'myu6hkt7': '',
#  'c7cjkatj': '',
#  'yiy3xfzc': '',
#  '2v4tw0ut': '',
#  'wwg6x1df': '',
#  'vyci1ho3': '',
#  'p6075gva': '',
#  'abepbwio': '',
#  'vsbckqdc': '',
#  'm27nyzrw': '',
#  'isavrupq': '',
#  'rooz9q18': '',
#  '2smn2hl5': '',
#  'i26lgvbz': '',
#  'c2lqffbf': '',
#  'gzc72bdy': '',
#  '0pp8en3a': '',
#  'ezmiwwzi': '',
#  'yxnq17cd': '',
#  '7z2aehta': '',
#  'fqaxuc7f': '',
#  'uhh3owcx': '',
#  'dgkmqenv': '',
#  'q3tlpkxm': '',
#  '8789ibcp': '',
#  'tdlj5smv': '',
#  'xcacty89': '',
#  '2zu5ffx2': '',
#  '2hdgartn': '',
#  'g60iybhk': '',
#  'x9al2tv6': '',
#  'pjddd1ft': '',
#  'c17j9dv7': '',
#  'szovsjrh': '',
#  'nxhazxja': '',
#  'or6h6p9p': '',
#  '2y146igt': '',
#  'v1wt5t7m': '',
#  'nvnywwcn': '',
#  'c6mgosdo': '',
#  'cijj983j': '',
#  'hol4dlfc': '',
#  'wgs69cu6': '',
#  'vdqq0j6l': '',
#  'x526x69v': '',
#  'tvlcsv2t': '',
#  'zyyhgcu8': '',
#  'qvjw4gt9': '',
#  '5evgp3k9': '',
#  '5yieno6w': '',
#  'q2otgybl': '',
#  'wuvq788p': '',
#  'v2zi8sm9': '',
#  'cy57hr8n': '',
#  '547k2e46': '',
#  'wbxtz30s': '',
#  'j0d6jtaz': '',
#  'vt4pniel': '',
#  'wb5rnfdf': '',
#  'xwbjmvvj': '',
#  'ub5l8hfu': '',
#  'mpf6lxxr': '',
#  'mtj46j82': '',
#  'qhc8b5x1': '',
#  'qqkd266u': '',
#  'uqsayb4d': '',
#  '0lbbiq7u': '',
#  'pg58hy81': '',
#  'tk7cl55p': '',
#  '3qdnnwvd': '',
#  'ot3wi5tc': '',
#  '2czhicqf': '',
#  'lcv5phyr': '',
#  '7uxqpenw': '',
#  '76aeat80': '',
#  'bg0fiyqq': '',
#  'zcya8kqh': '',
#  '6egc9led': '',
#  'plx59pwu': '',
#  'pvo7hs1x': '',
#  '8pqf7dnm': '',
#  'e1hcsnr7': '',
#  'exo2map8': '',
#  '3saha2xq': '',
#  'yhjggr51': '',
#  '82da7eli': '',
#  '4a5zy5wu': '',
#  'eas9u1mo': '',
#  'oxdsfxya': '',
#  'qcpcr7uv': '',
#  '5kbsd1mv': '',
#  's8j55hcu': '',
#  'cmw0lgpd': '',
#  'v9ry4xfa': '',
#  'ruk4p8rm': '',
#  'ojlf5s6q': '',
#  'nc6tqv9v': '',
#  'gzxu0r08': '',
#  'g1149fla': '',
#  'qb9pia62': '',
#  'dvw4ajtv': '',
#  'itlnpjg6': '',
#  'haszvpis': '',
#  '7meqqbhu': '',
#  'ox7db2xq': '',
#  'aeba20cx': '',
#  '10gscbkx': '',
#  '3v4vkcit': '',
#  '660ul4fb': '',
#  'wcobampz': '',
#  '94iieejz': '',
#  '5jk3u9b8': '',
#  'cy3ndif7': '',
#  'hzhd8tcr': '',
#  'qbt142yj': '',
#  '98f5rjnc': '',
#  '3um07feu': '',
#  'cc8wav9g': '',
#  'fdacxpmn': '',
#  '4sv862ur': '',
#  'ydcxel43': '',
#  'rhziowqv': '',
#  'xtwomrgw': '',
#  'gl5lozn9': '',
#  '26jg9g0b': '',
#  '645zegcv': '',
#  '6ayciihs': '',
#  'p79hblhi': '',
#  'gptjqti7': '',
#  'zn5tppbf': '',
#  'ppquta0q': '',
#  'a6avr09j': '',
#  'h2deyfhh': '',
#  'ou55t7ni': '',
#  'qntwv6t1': '',
#  '1yhehcjr': '',
#  '7pdtk0hu': '',
#  'hth8f5sn': '',
#  '3un6okdi': '',
#  '24fkn71p': '',
#  'vpdxbnul': '',
#  '450z0tv1': '',
#  'jqgx3o26': '',
#  'zwjvvio0': '',
#  'b7xjlqg3': '',
#  'xqvdko7p': '',
#  'daw45ik8': '',
#  'n2atn6nf': '',
#  'u5r5bx6s': '',
#  '7knn1voy': '',
#  'sxsrz60h': '',
#  'uj4ymadl': '',
#  'awi7bnsc': '',
#  '6d9x0xbj': '',
#  'kssigadb': '',
#  'g8m6n1u3': '',
#  '6i7e9dd4': '',
#  'n4y67x5p': '',
#  'eoz1l5fi': '',
#  '2wbvw0r9': '',
#  'ctipm54c': '',
#  'xf8160dx': '',
#  '2vyx0dzx': '',
#  'exhg840i': '',
#  'ofuwlu1z': '',
#  'k9cpbszs': '',
#  '8w6bxqx4': '',
#  'g7vihphf': '',
#  'ngow9w7p': '',
#  'mn3b6nrs': '',
#  'gihp7ulm': '',
#  '2ul2bp3g': '',
#  '0z0uabfw': '',
#  'xdblodz5': '',
#  'us96mt5k': '',
#  'l7c6j6o6': '',
#  '4fou5yy1': '',
#  'zmv598eq': '',
#  '311i3x9d': '',
#  'dfjh7qyh': '',
#  'n4berta0': '',
#  'rsl79cxo': '',
#  'vxaut12z': '',
#  'jerovngt': '',
#  'iu0h4p2u': '',
#  '270msv5l': '',
#  'mez1k8t0': '',
#  '6u623i0w': '',
#  '2f11w336': '',
#  'zss38mct': '',
#  'dubbjvwk': '',
#  '0faitr7v': '',
#  'tizeu01t': '',
#  'qkdni38b': '',
#  'qvhnly22': '',
#  '1hwm3cz0': '',
#  'j7tctong': '',
#  'sheq3iys': '',
#  '2es5dp9d': '',
#  '1xlf6h35': '',
#  'uuy2y0eu': '',
#  'h30rr2ut': '',
#  'o0kvg9uj': '',
#  'xjtapifg': '',
#  'mknkrocz': '',
#  'bdmu9cz2': '',
#  'uy2dlamj': '',
#  '1rghbp72': '',
#  'bzd1q20z': '',
#  'jlhykfbf': '',
#  'knheqmbj': '',
#  'ody5f2q7': '',
#  'yuvjpziu': '',
#  'nexfb60a': '',
#  'efxjxtgu': '',
#  '01jluimk': '',
#  's5keh3xw': '',
#  'ol75hgr6': '',
#  '9opqbu7h': '',
#  'uutppde3': '',
#  '47klft1o': '',
#  '25t4p4n8': '',
#  'ff7dg890': '',
#  'ladvfjma': '',
#  '5fi7spyu': '',
#  '6u3a9nez': '',
#  'lluqlzlg': '',
#  '5u6mhr82': '',
#  'qnac92vu': '',
#  'akaun6t1': '',
#  '04ftw7k9': '',
#  'kewnvb7p': '',
#  's006vxzk': '',
#  'oenuy07r': '',
#  'x5u6iapi': '',
#  'n0nch8he': '',
#  'lzfiv2br': '',
#  'n9l86dln': '',
#  'tysa2b5x': '',
#  'fn929z9y': '',
#  'x51jorbm': '',
#  'p0nwbgun': '',
#  'gvhjwqe7': '',
#  'mutsa6rb': '',
#  'vf8xhedi': '',
#  'ji83zmy7': '',
#  'h1i29kcq': '',
#  'ag3n4ecn': '',
#  '8yyac8z6': '',
#  'dp61v1ro': '',
#  '57og8rjy': '',
#  'nj1p4ehx': '',
#  'ipv0htpe': '',
#  'ibprgdh4': '',
#  's28whjgc': '',
#  '0y22emfh': '',
#  '6bmrqc5v': '',
#  '5hryh1ft': '',
#  'vnpki6qw': '',
#  'roftm446': '',
#  'wvm2ua95': '',
#  '5g6dn95u': '',
#  'yljhl3i1': '',
#  '6ld4xxsp': '',
#  'cv47h083': '',
#  'zgka74sr': '',
#  '8r45mjwq': '',
#  'vzfkstiw': '',
#  'wdpgo5km': '',
#  'mw6ujjrk': '',
#  '0dut9fjn': '',
#  '1qd5jmfo': '',
#  'nh34lgdh': '',
#  'tss3ubwp': '',
#  'vqkt24be': '',
#  't20huil6': '',
#  '2l1zw19o': '',
#  'ystfxgi1': '',
#  'tm4xjjjz': '',
#  'quep89jl': '',
#  'z98ags2x': '',
#  '79uefjom': '',
#  'fclg5hdm': '',
#  '3wl9ebdy': '',
#  'um9kefk4': '',
#  '5dq285kb': '',
#  'c8jsfj2n': '',
#  'czh7xqph': '',
#  'xexmlnkq': '',
#  '8q2ecffd': '',
#  'udlf9t1t': '',
#  'hky6isk2': '',
#  '4by61id3': '',
#  'lp4z75l8': '',
#  'du5ak60y': '',
#  'fpaswsug': '',
#  'g6w40a14': '',
#  '8eh90ber': '',
#  'l7zpo59y': '',
#  'sbryreho': '',
#  'op7go9f8': '',
#  '0jr5nlli': '',
#  'iqrxerqt': '',
#  'jb8228vn': '',
#  'wonwes6p': '',
#  'g91diczj': '',
#  'fas2ar3k': '',
#  'hyeayzyz': '',
#  'qkw27nfk': '',
#  'shnejtjt': '',
#  'il9vbbgk': '',
#  'q4u5t8zs': '',
#  'hqijd268': '',
#  '3ilttt6e': '',
#  'tolpbpsl': '',
#  'ltlmj824': '',
#  'pav9cx2p': '',
#  'hdw6bpnc': '',
#  'fqvrlrv0': '',
#  'y0xdizpq': '',
#  '5lcfxjkc': '',
#  'csggq1s2': '',
#  'pd8quqfy': '',
#  't79br3q7': '',
#  'rhpvd7ud': '',
#  'ox4dwecj': '',
#  'h72w22rm': '',
#  'pfccsgco': '',
#  '2q3e60fp': '',
#  'pfuyqc3u': '',
#  'uxghqdei': '',
#  ...}

# %%
for d in my_raw_documents.keys():
    if d not in docs:
        print(d)
        break
# Out:
# o81b9htu
